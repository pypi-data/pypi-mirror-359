# %% [markdown]
# # LLMs

# %%
from esperanto import AIFactory

messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What's the capital of France?"},
    ]


params = {
    "max_tokens": 850,
    "temperature": 1.0,
    "streaming": False,
    "top_p": 0.9,
    "structured": None
}

models = [
    ("openrouter", AIFactory.create_language("openrouter", "openai/gpt-4o")),
    ("openai", AIFactory.create_language("openai", "gpt-4o-mini")),
    ("xai", AIFactory.create_language("xai", "grok-3")),
    ("groq", AIFactory.create_language("groq", "llama3-8b-8192")),
    ("anthropic", AIFactory.create_language("anthropic", "claude-3-5-sonnet-latest")),
    ("ollama", AIFactory.create_language("ollama", "gemma3:4b")),
    ("google", AIFactory.create_language("google", "gemini-2.0-flash")),
    ("google", AIFactory.create_language("google", "gemini-2.5-pro-preview-06-05")),
    ("azure", AIFactory.create_language("azure", "gpt-4o-mini")),
    ("mistral", AIFactory.create_language("mistral", "mistral-large-latest")),
    ("deepseek", AIFactory.create_language("deepseek", "deepseek-chat")),
    ("vertex", AIFactory.create_language("vertex", "gemini-2.0-flash")),
]

# %% [markdown]
# ## List Models (WIP)

# %%
# for model in models:
#     try:
#         # Create an instance of the provider class
#         provider = model[0]
#         model_name = model[1]
#         print(f"\n=== {provider.upper()} Models ===")
#         print(provider.models)
#     except Exception as e:
#         print(f"Failed to get models for {provider}: {e}")

# %% [markdown]
# ## Chat Completion

# %% [markdown]
# ### Synchronous

# %%
for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        result = llm.chat_complete(messages)
        print(result.choices[0].message.content)
        print(result.content)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process {name}: {e}")
# Out:
# Results for openrouter:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for groq:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**. 😊
#
# Do you want to know anything else about Paris, or perhaps another country?
# The capital of France is **Paris**. 😊
#
# Do you want to know anything else about Paris, or perhaps another country?
#
# ==================================================
#
# Results for google:
# The capital of France is Paris.
#
# The capital of France is Paris.
#
#
# ==================================================
#
# Results for google:
# The capital of France is **Paris**.
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for azure:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for mistral:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France. If you have any other questions about France or anything else, feel free to ask!
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France. If you have any other questions about France or anything else, feel free to ask!
#
# ==================================================
#
# Results for deepseek:
# The capital of France is **Paris**. It is known for its iconic landmarks such as the Eiffel Tower, the Louvre Museum, and the Arc de Triomphe. Let me know if you'd like more details!
# The capital of France is **Paris**. It is known for its iconic landmarks such as the Eiffel Tower, the Louvre Museum, and the Arc de Triomphe. Let me know if you'd like more details!
#
# ==================================================
#
# Results for vertex:
# The capital of France is Paris.
#
# The capital of France is Paris.
#
#
# ==================================================

# %% [markdown]
# ### Asynchronous

# %%
for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        result = await llm.achat_complete(messages)
        print(result.choices[0].message.content)
        print(result.content)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process {name}: {e}")
# Out:
# Results for openrouter:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for groq:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris. It is also the largest city in France and one of the most populous cities in Europe.
# The capital of France is Paris. It is also the largest city in France and one of the most populous cities in Europe.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**.
#
# Do you want to know anything more about Paris, or would you like to ask me another question?
# The capital of France is **Paris**.
#
# Do you want to know anything more about Paris, or would you like to ask me another question?
#
# ==================================================
#
# Results for google:
# The capital of France is Paris.
#
# The capital of France is Paris.
#
#
# ==================================================
#
# Results for google:
# The capital of France is **Paris**.
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for azure:
# The capital of France is Paris.
# The capital of France is Paris.
#
# ==================================================
#
# Results for mistral:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for deepseek:
# The capital of France is **Paris**. It's known for its iconic landmarks like the Eiffel Tower, the Louvre Museum, and the Arc de Triomphe. Let me know if you'd like more details!
# The capital of France is **Paris**. It's known for its iconic landmarks like the Eiffel Tower, the Louvre Museum, and the Arc de Triomphe. Let me know if you'd like more details!
#
# ==================================================
#
# Results for vertex:
# The capital of France is Paris.
#
# The capital of France is Paris.
#
#
# ==================================================

# %% [markdown]
# ## JSON

# %%
import json

json_messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Please return the top 3 brazilian cities in JSON format. Dont include ```json```  in the response."},
    ]


for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        result = llm.chat_complete(json_messages)
        try:
            json_data = json.loads(result.choices[0].message.content)
            print(json_data)
        except json.JSONDecodeError:
            print("Error decoding JSON")
            print(result.choices[0].message.content)
        
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed {name}: {e}")
# Out:
# Results for openrouter:
# {'cities': [{'name': 'São Paulo', 'population': 12396372, 'state': 'São Paulo'}, {'name': 'Rio de Janeiro', 'population': 6775561, 'state': 'Rio de Janeiro'}, {'name': 'Brasília', 'population': 3055149, 'state': 'Distrito Federal'}]}
#
# ==================================================
#
# Results for openai:
# {'top_cities': [{'name': 'São Paulo', 'population': 12325232}, {'name': 'Rio de Janeiro', 'population': 6747815}, {'name': 'Salvador', 'population': 2902927}]}
#
# ==================================================
#
# Results for xai:
# {'cities': [{'rank': 1, 'name': 'São Paulo', 'state': 'São Paulo', 'population': '12,400,000 (approx)', 'note': 'Largest city and economic hub of Brazil'}, {'rank': 2, 'name': 'Rio de Janeiro', 'state': 'Rio de Janeiro', 'population': '6,700,000 (approx)', 'note': 'Known for its cultural landmarks and tourism'}, {'rank': 3, 'name': 'Brasília', 'state': 'Distrito Federal', 'population': '3,000,000 (approx)', 'note': 'Capital of Brazil, designed as a planned city'}]}
#
# ==================================================
#
# Results for groq:
# [{'Rank': 1, 'City': 'São Paulo', 'Population': 21740000}, {'Rank': 2, 'City': 'Rio de Janeiro', 'Population': 6123000}, {'Rank': 3, 'City': 'Salvador', 'Population': 2828000}]
#
# ==================================================
#
# Results for anthropic:
# {'top_brazilian_cities': [{'name': 'São Paulo', 'state': 'SP', 'population': 12325232}, {'name': 'Rio de Janeiro', 'state': 'RJ', 'population': 6747815}, {'name': 'Brasília', 'state': 'DF', 'population': 3055149}]}
#
# ==================================================
#
# Results for ollama:
# Error decoding JSON
# ```json
# {
#   "top_cities": [
#     {
#       "city": "São Paulo",
#       "population": 12393000,
#       "state": "São Paulo"
#     },
#     {
#       "city": "Rio de Janeiro",
#       "population": 6715000,
#       "state": "Rio de Janeiro"
#     },
#     {
#       "city": "Brasília",
#       "population": 3166000,
#       "state": "Distrito Federal"
#     }
#   ]
# }
# ```
#
# ==================================================
#
# Results for google:
# Error decoding JSON
# ```json
# {
#   "cities": [
#     {
#       "rank": 1,
#       "name": "São Paulo"
#     },
#     {
#       "rank": 2,
#       "name": "Rio de Janeiro"
#     },
#     {
#       "rank": 3,
#       "name": "Brasília"
#     }
#   ]
# }
# ```
#
#
# ==================================================
#
# Results for google:
# Failed google: 'parts'
# Results for azure:
# {'top_cities': [{'name': 'São Paulo', 'state': 'São Paulo'}, {'name': 'Rio de Janeiro', 'state': 'Rio de Janeiro'}, {'name': 'Salvador', 'state': 'Bahia'}]}
#
# ==================================================
#
# Results for mistral:
# {'cities': [{'name': 'São Paulo', 'population': 12325232}, {'name': 'Rio de Janeiro', 'population': 6718903}, {'name': 'Brasília', 'population': 3039446}]}
#
# ==================================================
#
# Results for deepseek:
# [{'city': 'São Paulo', 'population': 12325232, 'state': 'SP'}, {'city': 'Rio de Janeiro', 'population': 6747815, 'state': 'RJ'}, {'city': 'Brasília', 'population': 3055149, 'state': 'DF'}]
#
# ==================================================
#
# Results for vertex:
# Error decoding JSON
# ```json
# {
#   "cities": [
#     {
#       "rank": 1,
#       "city": "São Paulo",
#       "description": "The largest city in Brazil and a major financial center."
#     },
#     {
#       "rank": 2,
#       "city": "Rio de Janeiro",
#       "description": "Famous for its beaches, Christ the Redeemer statue, and Carnival."
#     },
#     {
#       "rank": 3,
#       "city": "Brasília",
#       "description": "The capital of Brazil, known for its modernist architecture."
#     }
#   ]
# }
# ```
#
#
# ==================================================

# %% [markdown]
# ### Pydantic (WIP)

# %%
# import json
# from pydantic import BaseModel
# from typing import List

# class Country(BaseModel):
#     name: str
#     population: int

# class Response(BaseModel):
#     countries: List[Country]

# json_messages = [
#         {"role": "system", "content": "You are a helpful assistant."},
#         {"role": "user", "content": "Please return the top 3 countries in terms of population. Responda no formato JSON."},
#     ]


# for name, config in models.items():
#     try:
#         llm = config["class"](model_name=config["model"], structured={"type": "json", "model": Response})
#         print(f"Results for {llm.provider}:")
#         result = llm.chat_complete(json_messages)
#         try:
#             json_data = json.loads(result.choices[0].message.content)
#             print(json_data)
#         except json.JSONDecodeError:
#             print("Error decoding JSON")
        
#         print("\n" + "="*50 + "\n")
#     except Exception as e:
#         print(f"Failed to get models for {name}: {e}")

# %% [markdown]
# ## Streaming

# %% [markdown]
# ### Synchronous

# %%
for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        result = llm.chat_complete(
            messages, stream=True
        )

        for chunk in result:
            print(chunk)
        print("\n" + "="*50 + "\n")
    except Exception as e:
            print(f"Failed to process for {name}: {e}")
# Out:
# Results for openrouter:
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
# id='gen-1749347557-HEUSl1rnORnaXQEH8LM5' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347557 object='chat.completion.chunk'
#
# ==================================================
#
# Results for openai:
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
# id='chatcmpl-BfzV8KcdmZ2Qox978asfrRi81jmET' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gpt-4o-mini-2024-07-18' created=1749347558 object='chat.completion.chunk'
#
# ==================================================
#
# Results for xai:
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347559 object='chat.completion.chunk'
# id='f1aeb7a6-ddc3-43f9-a8ff-7c7e6a5abcd2' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='grok-3' created=1749347559 object='chat.completion.chunk'
#
# ==================================================
#
# Results for groq:
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content='!', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
# id='chatcmpl-1ddfda85-8b59-418d-ad05-8ff060391b2d' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='llama3-8b-8192' created=1749347560 object='chat.completion.chunk'
#
# ==================================================
#
# Results for anthropic:
# id='e01d31cb-0d9a-41fe-907e-48f45326ed86' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The capital of France is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='claude-3-5-sonnet-latest' created=1749347562 object='chat.completion.chunk'
# id='b87f5fd8-491e-4c93-bd59-f2478edc49aa' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='claude-3-5-sonnet-latest' created=1749347562 object='chat.completion.chunk'
# id='f2b22274-fa66-4bfb-a808-98254fd90085' choices=[StreamChoice(index=0, delta=DeltaMessage(content=None, role='assistant', function_call=None, tool_calls=None), finish_reason='end_turn')] model='claude-3-5-sonnet-latest' created=1749347562 object='chat.completion.chunk'
#
# ==================================================
#
# Results for ollama:
# id='b9adaad8-4d2d-401f-ad56-b678a8652e56' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='fd423f5b-ada0-428f-b01f-94cb5bb7fcae' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='54ff0780-40b4-43bb-a6fe-ffdf9f9d57ef' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='2174e76f-9d6c-43a9-8bb6-a5f6ec763fda' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='16292386-1413-49d2-b49d-9b1783d9e054' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='bee0355d-0f7b-4f09-84dd-5f12dddafca8' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' **', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='c9289bc1-ce61-4cd1-8a23-f512ba3349fa' choices=[StreamChoice(index=0, delta=DeltaMessage(content='Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='858dd6d6-304a-4854-ab8c-c3a5bcc9fe61' choices=[StreamChoice(index=0, delta=DeltaMessage(content='**.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='ad0e73ed-0a59-4a2e-8e23-4a17b33abbfe' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' ', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='f76d58ff-715a-4c20-afec-4097530eba5b' choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n\n', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='5706a3af-1626-43c2-9395-0f74f8ae3ed2' choices=[StreamChoice(index=0, delta=DeltaMessage(content='Do', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='ed2bd772-0138-4b7d-b605-e0e0cde3d844' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' you', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='9d32d702-01af-4a58-b7ab-a2bd60888e5f' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' want', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='6eb10ca7-3daf-4d21-9773-f3bde94fae96' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' to', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='94556206-ac5c-4c98-aaed-0064b7fd5be3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' know', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='7bb28184-c132-4f2d-92dd-473b260b9e63' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' anything', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='03e84c95-1035-4347-b0ab-6eebcfaecb94' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' more', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='a2d25974-041f-476e-aabd-4827c1fa897b' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' about', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='73f8695c-8470-46ab-9080-5dc2a73369a7' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='96e11963-b1e6-447a-9631-134064a0e4d2' choices=[StreamChoice(index=0, delta=DeltaMessage(content=',', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='6ed73755-0162-42e8-83ee-3312926c242e' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='7cd28e02-ad7a-430f-b7f3-461dfaaeeea8' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' its', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='9d5a4fdf-32ab-4574-b288-67e8c9c45fb8' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' famous', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='892ee529-5e82-45c0-8c7b-b918f2b41708' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' landmarks', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='14729caf-dab1-4610-8713-256fbbc02a8d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' or', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='b9dff60e-a423-4d7c-b379-dd59b7999533' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' history', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='af3be41d-cfc2-4630-9329-cc35a91ca58b' choices=[StreamChoice(index=0, delta=DeltaMessage(content='?', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
# id='4b97bbf4-5f7d-44a1-bbb8-809f5149fea1' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemma3:4b' created=1749347562 object='chat.completion.chunk'
#
# ==================================================
#
# Results for google:
# id='a420a914-f520-4978-9bee-36726e519edd' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemini-2.0-flash' created=1749347563 object='chat.completion.chunk'
# id='8dc4bd89-8ed1-49b0-adbf-b4bb8f62483d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemini-2.0-flash' created=1749347563 object='chat.completion.chunk'
# id='a1831f12-fc56-432b-9885-3163eea62a74' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is Paris.\n', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemini-2.0-flash' created=1749347563 object='chat.completion.chunk'
#
# ==================================================
#
# Results for google:
# id='77cd4886-2e32-4d76-9afb-bd6784eed3fa' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The capital of France is **Paris**.', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemini-2.5-pro-preview-06-05' created=1749347568 object='chat.completion.chunk'
#
# ==================================================
#
# Results for azure:
# id='' choices=[] model='gpt-4o-mini' created=0 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
# id='chatcmpl-BfzVJptTlDkAsTn739k6cHuWTTXRL' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gpt-4o-mini-2024-07-18' created=1749347569 object='chat.completion.chunk'
#
# ==================================================
#
# Results for mistral:
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=". It's", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' known', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' for icon', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content='ic landmarks like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the Eiffel', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Tower, the Lou', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content='vre Museum, and', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Notre-D', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content='ame Cathedral.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' It', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'s also", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the largest', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' city in France.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
# id='e379208476ca4a8bb7ca7b0a7a37c97c' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='mistral-large-latest' created=1749347570 object='chat.completion.chunk'
#
# ==================================================
#
# Results for deepseek:
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' **', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='**.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' It', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'s", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' known', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' for', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' its', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' iconic', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' landmarks', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' E', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='iff', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='el', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Tower', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=',', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Louvre', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Museum', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=',', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' and', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Notre', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='-D', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='ame', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Cathedral', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Let', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' me', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' know', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' if', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' you', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'d", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' more', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' details', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='!', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' 😊', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
# id='b6acefed-0a5b-40e9-a6fc-d4091b8a3225' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='deepseek-chat' created=1749347571 object='chat.completion.chunk'
#
# ==================================================
#
# Results for vertex:
# id='5aa44cf8-2959-433b-986f-0b521e056676' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The capital of France is Paris.\n', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemini-2.0-flash' created=1749347577 object='chat.completion.chunk'
#
# ==================================================

# %%
for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        result = await llm.achat_complete(
            messages, stream=True
        )

        async for chunk in result:
            print(chunk)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process for {name}: {e}")
# Out:
# Results for openrouter:
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
# id='gen-1749347577-582dpHTjeh7kKvwUQwSu' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='openai/gpt-4o' created=1749347577 object='chat.completion.chunk'
#
# ==================================================
#
# Results for openai:
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
# id='chatcmpl-BfzVSQg84esHfOcWAPNMR4wS3AanQ' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gpt-4o-mini-2024-07-18' created=1749347578 object='chat.completion.chunk'
#
# ==================================================
#
# Results for xai:
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347579 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347580 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347580 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347580 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347580 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347580 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='grok-3' created=1749347580 object='chat.completion.chunk'
# id='316a0e03-6369-4c89-9045-6e51a8d79b30' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='grok-3' created=1749347580 object='chat.completion.chunk'
#
# ==================================================
#
# Results for groq:
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content='That', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'s", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' an', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' easy', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' one', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content='!', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
# id='chatcmpl-6e62a544-8760-4db0-9057-780b4a61df43' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='llama3-8b-8192' created=1749347580 object='chat.completion.chunk'
#
# ==================================================
#
# Results for anthropic:
# id='d9283f88-6655-4185-a570-841948b502ae' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The capital of France is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='claude-3-5-sonnet-latest' created=1749347582 object='chat.completion.chunk'
# id='c39c5a83-0ad2-49d8-90ae-16ee2ad21fb7' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='claude-3-5-sonnet-latest' created=1749347582 object='chat.completion.chunk'
# id='05766726-e615-4377-b6cc-e8c144e1d77a' choices=[StreamChoice(index=0, delta=DeltaMessage(content=None, role='assistant', function_call=None, tool_calls=None), finish_reason='end_turn')] model='claude-3-5-sonnet-latest' created=1749347582 object='chat.completion.chunk'
#
# ==================================================
#
# Results for ollama:
# id='4e474d4d-0771-4f1d-bab1-645f79720222' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='d97e39d8-4274-4260-ae15-becc85921a41' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='3106edab-6a9c-4bf3-a72b-6146ecc44d3e' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='e9ef3747-47c3-4393-bf0e-9f8625de9798' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='b7f26300-82f5-49c0-9f8d-b7cf9860714d' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='a8bf5a44-12e1-4e74-b4f2-a6fa1b0f9211' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' **', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='8ee979de-b916-4b23-90e7-1b7537d68b73' choices=[StreamChoice(index=0, delta=DeltaMessage(content='Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='ada1cb6d-071c-4e10-8a6a-58d2bdbf36e1' choices=[StreamChoice(index=0, delta=DeltaMessage(content='**.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='4eee0136-6e54-49c4-a469-d9d10a6d2f1c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' 😊', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='725e7d78-c4dd-4fc9-983f-f990b08fbffb' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' ', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='61911693-dca4-4887-be2f-882341baf779' choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n\n', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='6e1f3e6c-7a17-44b3-8acb-f9fb9ba3858a' choices=[StreamChoice(index=0, delta=DeltaMessage(content='Do', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='249940ff-303a-4e39-a10c-a7cb5afd3d0b' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' you', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='2bbcbde1-6bc0-4836-a0f0-878d00511fac' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' want', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='638733e9-6b36-44bf-b99b-0b9c3f95bbcc' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' to', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='aae81ed3-f871-41b7-a095-a01d6ab27b9a' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' know', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='18026621-c494-442b-ad6d-069dc59a15fc' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' anything', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='50aa0f48-c9c1-47c8-b2e9-43acf62bbf69' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' else', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='1618a9a9-f7b5-4d9b-82f7-e7df0f35a56f' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' about', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='d7ec3f0c-fbbb-4e64-9406-e8545928ab32' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='d49693f0-0185-4d6d-a43c-3bafbc11e5c8' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' or', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='d5ec34c9-5c13-4972-b6c6-6966b1be224c' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='5d1e85a7-dc65-4327-a1f5-a39b9ee0f213' choices=[StreamChoice(index=0, delta=DeltaMessage(content='?', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
# id='7d83e336-b653-4b73-8522-7c7288d07749' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemma3:4b' created=1749347582 object='chat.completion.chunk'
#
# ==================================================
#
# Results for google:
# id='5458891b-972c-47e7-8686-b5995bafe72e' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemini-2.0-flash' created=1749347583 object='chat.completion.chunk'
# id='a9bd5512-04a2-46a9-a1ec-035ad6283ae7' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gemini-2.0-flash' created=1749347583 object='chat.completion.chunk'
# id='6b20d38e-5231-4cfc-a407-4c209f229020' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is Paris.\n', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemini-2.0-flash' created=1749347583 object='chat.completion.chunk'
#
# ==================================================
#
# Results for google:
# id='e46a0bdf-500f-4d4f-869d-458d7be26a00' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The capital of France is **Paris**.', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemini-2.5-pro-preview-06-05' created=1749347588 object='chat.completion.chunk'
#
# ==================================================
#
# Results for azure:
# id='' choices=[] model='gpt-4o-mini' created=0 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
# id='chatcmpl-BfzVcyWu7fiTM8AsIU0RTQR3jDYef' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gpt-4o-mini-2024-07-18' created=1749347588 object='chat.completion.chunk'
#
# ==================================================
#
# Results for mistral:
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=". It's", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' known', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' for icon', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content='ic landmarks like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the Eiffel', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Tower, the Lou', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content='vre Museum, and', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Notre-D', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content='ame Cathedral.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' It', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'s also the", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' largest', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' city in France.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
# id='d2f69c0f21ef4f71a8f088566699f9f6' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='mistral-large-latest' created=1749347589 object='chat.completion.chunk'
#
# ==================================================
#
# Results for deepseek:
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' **', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='Paris', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='**.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' It', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'s", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' known', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' for', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' its', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' iconic', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' landmarks', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' E', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='iff', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='el', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Tower', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=',', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Louvre', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Museum', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=',', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' and', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' the', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Arc', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' de', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Tri', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='om', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='phe', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Let', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' me', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' know', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' if', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' you', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content="'d", role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' like', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' more', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content=' details', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='!', role='assistant', function_call=None, tool_calls=None), finish_reason='None')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
# id='a4e9cfb5-d959-43c6-a02e-ba04521144a3' choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='deepseek-chat' created=1749347590 object='chat.completion.chunk'
#
# ==================================================
#
# Results for vertex:
# id='b5f7337d-09ce-464d-aa39-16499fa44581' choices=[StreamChoice(index=0, delta=DeltaMessage(content='The capital of France is Paris.\n', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')] model='gemini-2.0-flash' created=1749347596 object='chat.completion.chunk'
#
# ==================================================

# %% [markdown]
# ## LangChain

# %% [markdown]
# ### Synchronous

# %%
for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        model = llm.to_langchain()
        response = model.invoke(messages)
        print(response.content)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process for {name}: {e}")
# Out:
# Results for openrouter:
# The capital of France is Paris.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for groq:
# The capital of France is Paris.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris. It is also the largest city in France and one of the most populous cities in Europe. Paris is a major global center for art, culture, fashion, and cuisine, and is home to iconic landmarks such as the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**.
#
# Do you want to know anything else about Paris, or perhaps another country's capital? 😊
#
# ==================================================
#
# Results for google:
# The capital of France is Paris.
#
# ==================================================
#
# Results for google:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for azure:
# The capital of France is Paris.
#
# ==================================================
#
# Results for mistral:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for deepseek:
# The capital of France is **Paris**. It's known for its iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. Let me know if you'd like more details!
#
# ==================================================
#
# Results for vertex:
# The capital of France is Paris.
#
#
# ==================================================

# %% [markdown]
# ### Asynchronous

# %%
for name, llm in models:
    try:
        print(f"Results for {llm.provider}:")
        model = llm.to_langchain()
        response = await model.ainvoke(messages)
        print(response.content)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process for {name}: {e}")
# Out:
# Results for openrouter:
# The capital of France is Paris.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for groq:
# That's an easy one! The capital of France is Paris.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**.
#
# Do you want to know anything else about Paris or France? 😊
#
# ==================================================
#
# Results for google:
# The capital of France is Paris.
#
# ==================================================
#
# Results for google:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for azure:
# The capital of France is Paris.
#
# ==================================================
#
# Results for mistral:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for deepseek:
# The capital of France is **Paris**. It's known for its iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. Let me know if you'd like more details!
#
# ==================================================
#
# Results for vertex:
# The capital of France is Paris.
#
#
# ==================================================

# %% [markdown]
# ### Streaming

# %%
for name, llm in models:
    try:
        llm = llm(model_name=llm.model_name, streaming=True)
        print(f"Results for {llm.provider}:")
        model = llm.to_langchain()
        response = model.stream(messages)
        for chunk in response:
            print(chunk)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process for {name}: {e}")
# Out:
# Failed to process for openrouter: 'OpenRouterLanguageModel' object is not callable
# Failed to process for openai: 'OpenAILanguageModel' object is not callable
# Failed to process for xai: 'XAILanguageModel' object is not callable
# Failed to process for groq: 'GroqLanguageModel' object is not callable
# Failed to process for anthropic: 'AnthropicLanguageModel' object is not callable
# Failed to process for ollama: 'OllamaLanguageModel' object is not callable
# Failed to process for google: 'GoogleLanguageModel' object is not callable
# Failed to process for google: 'GoogleLanguageModel' object is not callable
# Failed to process for azure: 'AzureLanguageModel' object is not callable
# Failed to process for mistral: 'MistralLanguageModel' object is not callable
# Failed to process for deepseek: 'DeepSeekLanguageModel' object is not callable
# Failed to process for vertex: 'VertexLanguageModel' object is not callable

# %% [markdown]
# ### Asynchronous Streaming

# %%
for name, llm in models:
    try:
        llm = llm(model_name=llm.model_name, streaming=True)
        print(f"Results for {llm.provider}:")
        model = llm.to_langchain()
        response = model.astream(messages)
        async for chunk in response:
            print(chunk)
        print("\n" + "="*50 + "\n")
    except Exception as e:
        print(f"Failed to process for {name}: {e}")
# Out:
# Failed to process for openrouter: 'OpenRouterLanguageModel' object is not callable
# Failed to process for openai: 'OpenAILanguageModel' object is not callable
# Failed to process for xai: 'XAILanguageModel' object is not callable
# Failed to process for groq: 'GroqLanguageModel' object is not callable
# Failed to process for anthropic: 'AnthropicLanguageModel' object is not callable
# Failed to process for ollama: 'OllamaLanguageModel' object is not callable
# Failed to process for google: 'GoogleLanguageModel' object is not callable
# Failed to process for google: 'GoogleLanguageModel' object is not callable
# Failed to process for azure: 'AzureLanguageModel' object is not callable
# Failed to process for mistral: 'MistralLanguageModel' object is not callable
# Failed to process for deepseek: 'DeepSeekLanguageModel' object is not callable
# Failed to process for vertex: 'VertexLanguageModel' object is not callable
