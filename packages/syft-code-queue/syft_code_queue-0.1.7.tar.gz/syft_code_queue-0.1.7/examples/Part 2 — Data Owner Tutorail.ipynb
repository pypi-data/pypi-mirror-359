# %%
import syft_code_queue as q
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/organic-coop-enclave/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3672 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import syft_code_queue as q
#
#   File ~/Desktop/organic-coop-enclave/syft-code-queue/src/syft_code_queue/__init__.py:35
#     from .client import CodeQueueClient, create_client
#
#   File ~/Desktop/organic-coop-enclave/syft-code-queue/src/syft_code_queue/client.py:33
#     from .models import CodeJob, JobCreate, JobStatus, QueueConfig
#
#   File ~/Desktop/organic-coop-enclave/syft-code-queue/src/syft_code_queue/models.py:1293
#     const jobUid = row.getAttribute('data-job-uid'); if (jobUid) { selectedUids.push(jobUid); }
#                                                                                             ^
# SyntaxError: f-string: expecting '=', or '!', or ':', or '}'

# %%
q.pending_for_me
# Out:
# JobCollection(4 jobs - pending: 4)

# %%
import syft_code_queue as q
approved_count = 0
if len(q.pending_for_me) > 0:
    if q.pending_for_me[0].approve("Batch approved via Jupyter interface"):  
        approved_count += 1
if len(q.pending_for_me) > 1:
    if q.pending_for_me[1].approve("Batch approved via Jupyter interface"):  
        approved_count += 1
if len(q.pending_for_me) > 2:
    if q.pending_for_me[2].approve("Batch approved via Jupyter interface"):  
        approved_count += 1
if len(q.pending_for_me) > 3:
    if q.pending_for_me[3].approve("Batch approved via Jupyter interface"):  
        approved_count += 1
print(f"✅ Approved {approved_count} job(s)")
